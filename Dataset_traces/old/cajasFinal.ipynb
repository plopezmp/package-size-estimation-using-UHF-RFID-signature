# %% [markdown]
# # Practical box size estimation from RFID interrogation traces using transfer learning

# %% [markdown]
# Instrucciones:
#
# - Realizar por cada dataset un entrenamiento probando cual es la precisión alcanzada

# %%
# Bibliotecas necesarias
import numpy as np
import random
import os

# Configuramos matplotlib
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# %load_ext tensorboard

# Semilla fija para reproducibilidad
np.random.seed(1)

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# <style>.container { width:100% !important; }</style>

# %%
import pandas
import pickle

def change_distro(X,t,samples):  
    newX = np.zeros(shape=[samples.sum(),X.shape[1]])
    newt = np.zeros(shape=[samples.sum(),])
    numsamples = 0
    for i in range(t.max()+1):
        aux = X[t==i]
        newX[numsamples:numsamples+samples[i]] = aux[:samples[i]]
        newt[numsamples:numsamples+samples[i]] = i
        numsamples += samples[i]
    
    newt = newt.astype(int)
    return newX,newt

def readdataset(id, maxsize=0, debug=False):
    picklefile = f'{id}/data.pickle'

    try:
        with open(picklefile, 'rb') as f:
            X, t = pickle.load(f)
            print(f'Datos ya disponibles de {picklefile}')
    
    except:
        index = pandas.read_csv(f'{id}/index.{id}.txt')
        index["numframes"] = index.framelst-index.frameini+1
        maxframes = index.numframes.max()
        frames = pandas.read_csv(f'{id}/frames.{id}.txt')
    
        if maxsize>0:
            SAMPLES = maxsize
        else:
            SAMPLES = len(index)
            
        if debug:
            print(f'Samples: {SAMPLES}')
            
        X = np.zeros(shape=[SAMPLES, 23]) 
        t = np.zeros(shape=[SAMPLES, ]) 
    
        for i in range(SAMPLES):
            if maxsize>0:
                batch = random.randint(0,SAMPLES-1)
            else:
                batch = i
            tagsread = index.iloc[batch].tagsread
            readtime = index.iloc[batch].readtime
            numframes = index.iloc[batch].numframes
            framebase = int(index.iloc[batch].frameini) 
            aux = frames.loc[framebase:framebase+numframes-1].values
            X[i,0] = tagsread
            X[i,1] = readtime
            X[i,2] = numframes
            X[i,3:8] = aux.mean(axis=0)
            X[i,8:13] = aux.std(axis=0)
            X[i,13:18] = aux.min(axis=0)
            X[i,18:23] = aux.max(axis=0)
            t[i] = index.iloc[batch].boxoriginal
            #X[batch,3:3+numframes*5] = frames.loc[framebase:framebase+numframes-1].values.ravel()
            if (debug) and ((i+1)%5000)==0:
                print(f'i: {i+1}, batch: {batch}, frames: {numframes}, framebase: {framebase}, t: {t[i]}, aux: {aux}')
        
            t = t.astype(int)
   
        with open(picklefile, 'wb') as f:
            pickle.dump([X, t], f)
    
        if debug: 
            frames.head(-1)
            
    return X,t

# %%
import keras
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

import tensorflow as tf
from sklearn.metrics import confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping
from keras.callbacks import TensorBoard

def evalmodel(X,t,id,debug=False):  
    if debug:
        modelname = f'{id}/model.h5'
    X_train, X_test, t_train, t_test =  train_test_split(X, t, test_size=0.8)
    
    standard_transformer = Pipeline(steps=[('standard', StandardScaler())])
    minmax_transformer = Pipeline(steps=[('minmax', MinMaxScaler())])
    preprocessor = ColumnTransformer(
        remainder='passthrough', #passthough features not listed
        transformers=[
            ('std', standard_transformer , []),#slice(0,X.shape[1])),
            ('mm', minmax_transformer , slice(0,X.shape[1]))
        ])
    X_train = preprocessor.fit_transform(X_train)
    X_test = preprocessor.transform(X_test)
    model = keras.models.Sequential([
        keras.layers.Dense(100, activation="relu", input_shape=X_train.shape[1:]),
        keras.layers.Dense(50, activation="tanh"),
        keras.layers.Dense(int(t.max())+1, activation="sigmoid")
    ])
    
    try: 
        model = keras.models.load_model(modelname) # cargar modelo
    except:
        early_stopping_cb = EarlyStopping(patience=20, restore_best_weights=True)
        checkpoint_cb = ModelCheckpoint(modelname, save_best_only=True)
        tensorboard_cb = TensorBoard(f'{id}/log', histogram_freq=1)
        model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
        model.fit(X_train, t_train, epochs=50000
                  , validation_data=(X_test, t_test), batch_size=32, callbacks=[early_stopping_cb, checkpoint_cb, tensorboard_cb], verbose=0)
        keras.models.save_model(modelname)
    
    precision = model.evaluate(X_test,t_test)[1]
    y_test = model.predict_classes(X_test)
    conf = confusion_matrix(list(map(int,t_test)), y_test)
    
    return precision, conf

# %%
# %tensorboard --logdir 'IMP/log'
X, t = readdataset('IMP')
precision, conf = evalmodel(X,t,'IMP', debug=True)
print(f'ac: {precision}, cm: {conf}')
# Out:
# Launching TensorBoard...

# %%
SAMPLES_BATCH = 200
NUM_BATCHES = 100

XX = np.zeros(shape=[SAMPLES_BATCH, 23]) 
tt = np.zeros(shape=[SAMPLES_BATCH, ]) 
print(f'XX.shape: {XX.shape}')

mejora = 0.0
mejora_independiente = 0.0

for batch in range(NUM_BATCHES):
    # batch = random.randint(0,100) 
    for i in range(SAMPLES_BATCH):
        tagsread = index_ajuste.iloc[batch+i].tagsread
        readtime = index_ajuste.iloc[batch+i].readtime
        numframes = index_ajuste.iloc[batch+i].numframes
        framebase = int(index_ajuste.iloc[batch+i].frameini) 
        ha = index_ajuste.iloc[batch+i].ha
        hb = index_ajuste.iloc[batch+i].hb
        d = index_ajuste.iloc[batch+i].d
        aux = frames_ajuste.loc[framebase:framebase+numframes-1].values
        XX[i,0] = tagsread
        XX[i,1] = readtime
        XX[i,2] = numframes
        XX[i,3:8] = aux.mean(axis=0)
        XX[i,8:13] = aux.std(axis=0)
        XX[i,13:18] = aux.min(axis=0)
        XX[i,18:23] = aux.max(axis=0)
        tt[i] = index_ajuste.iloc[batch+i].boxoriginal
    #    if (i+1)%50==0:
    #        print(f'i: {i+1}, batch: {batch}, frames: {numframes}, framebase: {framebase}, tt: {tt[i]}, aux: {aux}, ha: {ha}, hb: {hb}, d: {d}')

    # Vemos resultado con la red anterior sin ajustar. Debe ser malo por no tener ningun dato de esta red
    XX_transform = preprocessor.transform(XX)
    precision_modelo_original = model.evaluate(XX_transform,tt)[1]
    print(f'precision_modelo_original: {precision_modelo_original*100:.02f}%')

    # Probamos usando solo dataset de ajuste. Separamos el conjunto de ajuste en train (100) y test (100)
    XX_train, XX_test, tt_train, tt_test =  train_test_split(XX, tt, test_size=0.5)
    preprocessor_ajuste = ColumnTransformer(
            remainder='passthrough', #passthough features not listed
            transformers=[
                ('std', standard_transformer , []),#slice(0,X.shape[1])),
                ('mm', minmax_transformer , slice(0,X.shape[1]))
            ])
    XX_train = preprocessor_ajuste.fit_transform(XX_train)
    XX_test = preprocessor_ajuste.transform(XX_test)
    model_ajuste = keras.models.Sequential([
        keras.layers.Dense(100, activation="relu", input_shape=X_train.shape[1:]),
        keras.layers.Dense(50, activation="tanh"),
        keras.layers.Dense(int(t.max())+1, activation="sigmoid")
    ])
    model_ajuste.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
    model_ajuste.fit(XX_train, tt_train, epochs=50000,  validation_data=(XX_test, tt_test),  batch_size=32, callbacks=[early_stopping_cb], verbose=0)
    precision_modelo_independiente = model_ajuste.evaluate(XX_test,tt_test)[1]
    print(f'precision_modelo_independiente: {precision_modelo_independiente*100:.02f}%')

    # Ajuste mejorado del modelo original con transfer learning
    XX_train, XX_test, tt_train, tt_test =  train_test_split(preprocessor.transform(XX), tt, test_size=0.5)
    model_copy= keras.models.clone_model(model)
    model_copy.build((None, XX.shape[1])) # replace 10 with number of variables in input layer
    model_copy.set_weights(model.get_weights())
    model_copy.layers[0].trainable = False
    model_copy.layers[1].trainable = False
    model_copy.layers[2].trainable = False
    #for l in model_copy.layers:
    #    print(l.name, l.trainable)
    model_copy.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=["accuracy"])

    model_copy.fit(XX_train, tt_train, epochs=5000,  validation_data=(XX_test, tt_test),  batch_size=32, callbacks=[early_stopping_cb], verbose=0)
    precision_modelo_copia = model_copy.evaluate(XX_test,tt_test)[1]
    print(f'precision_modelo_copia: {precision_modelo_copia*100:.02f}%')

    mejora += (precision_modelo_copia - precision_modelo_original)/NUM_BATCHES
    mejora_independiente += (precision_modelo_copia - precision_modelo_independiente)/NUM_BATCHES
    
    
print(f'Mejora: {mejora*100:.02f}%')
print(f'Mejora independiente: {mejora_independiente*100:.02f}%')
# Out:
# XX.shape: (200, 23)
# 200/200 [==============================] - 0s 68us/step
# precision_modelo_original: 24.50%
# 100/100 [==============================] - 0s 89us/step
# precision_modelo_independiente: 25.00%
# 100/100 [==============================] - 0s 92us/step
# precision_modelo_copia: 33.00%
# 200/200 [==============================] - 0s 69us/step
# precision_modelo_original: 24.50%
# 100/100 [==============================] - 0s 90us/step
# precision_modelo_independiente: 22.00%
# 100/100 [==============================] - 0s 90us/step
# precision_modelo_copia: 23.00%
# 200/200 [==============================] - 0s 73us/step
# precision_modelo_original: 24.50%
# 100/100 [==============================] - 0s 87us/step
# precision_modelo_independiente: 21.00%
# 100/100 [==============================] - 0s 88us/step
# precision_modelo_copia: 25.00%
# 200/200 [==============================] - 0s 60us/step
# precision_modelo_original: 24.50%
# 100/100 [==============================] - 0s 84us/step
# precision_modelo_independiente: 24.00%
# 100/100 [==============================] - 0s 121us/step
# precision_modelo_copia: 33.00%
# 200/200 [==============================] - 0s 70us/step
# precision_modelo_original: 24.00%
# 100/100 [==============================] - 0s 88us/step
# precision_modelo_independiente: 19.00%
# 100/100 [==============================] - 0s 92us/step
# precision_modelo_copia: 29.00%
# 200/200 [==============================] - 0s 76us/step
# precision_modelo_original: 24.00%
# 100/100 [==============================] - 0s 85us/step
# precision_modelo_independiente: 36.00%
# 100/100 [==============================] - 0s 93us/step
# precision_modelo_copia: 27.00%
# 200/200 [==============================] - 0s 66us/step
# precision_modelo_original: 23.50%
# 100/100 [==============================] - 0s 98us/step
# precision_modelo_independiente: 19.00%
# 100/100 [==============================] - 0s 92us/step
# precision_modelo_copia: 34.00%
# 200/200 [==============================] - 0s 74us/step
# precision_modelo_original: 23.50%
# 100/100 [==============================] - 0s 89us/step
# precision_modelo_independiente: 26.00%
# 100/100 [==============================] - 0s 94us/step
# precision_modelo_copia: 22.00%
# 200/200 [==============================] - 0s 68us/step
# precision_modelo_original: 23.50%
# 100/100 [==============================] - 0s 89us/step
# precision_modelo_independiente: 23.00%
# 100/100 [==============================] - 0s 98us/step
# precision_modelo_copia: 27.00%
# 200/200 [==============================] - 0s 64us/step
# precision_modelo_original: 23.50%
# 100/100 [==============================] - 0s 92us/step
# precision_modelo_independiente: 33.00%
# 100/100 [==============================] - 0s 95us/step
# precision_modelo_copia: 31.00%
# 200/200 [==============================] - 0s 100us/step
# precision_modelo_original: 23.50%
# 100/100 [==============================] - 0s 99us/step
# precision_modelo_independiente: 19.00%
# 100/100 [==============================] - 0s 99us/step
# precision_modelo_copia: 33.00%
# 200/200 [==============================] - 0s 71us/step
# precision_modelo_original: 23.00%
# 100/100 [==============================] - 0s 92us/step
# precision_modelo_independiente: 28.00%
# 100/100 [==============================] - 0s 87us/step
# precision_modelo_copia: 32.00%
# 200/200 [==============================] - 0s 60us/step
# precision_modelo_original: 23.50%
# 100/100 [==============================] - 0s 86us/step
# precision_modelo_independiente: 18.00%
# 100/100 [==============================] - 0s 88us/step
# precision_modelo_copia: 25.00%
# 200/200 [==============================] - 0s 63us/step
# precision_modelo_original: 23.50%
# 100/100 [==============================] - 0s 84us/step
# precision_modelo_independiente: 23.00%
# 100/100 [==============================] - 0s 84us/step
# precision_modelo_copia: 25.00%
# 200/200 [==============================] - 0s 61us/step
# precision_modelo_original: 23.50%
# 100/100 [==============================] - 0s 89us/step
# precision_modelo_independiente: 19.00%
# 100/100 [==============================] - 0s 99us/step
# precision_modelo_copia: 33.00%
# 200/200 [==============================] - 0s 72us/step
# precision_modelo_original: 23.50%
# 100/100 [==============================] - 0s 103us/step
# precision_modelo_independiente: 19.00%
# /Users/javiervalesalonso/opt/anaconda3/envs/ml/lib/python3.7/site-packages/keras/callbacks/callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.102035). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 100/100 [==============================] - 0s 94us/step
# precision_modelo_copia: 31.00%
# 200/200 [==============================] - 0s 76us/step
# precision_modelo_original: 23.50%
# 100/100 [==============================] - 0s 88us/step
# precision_modelo_independiente: 18.00%
# 100/100 [==============================] - 0s 89us/step
# precision_modelo_copia: 23.00%
# 200/200 [==============================] - 0s 62us/step
# precision_modelo_original: 23.50%
# 100/100 [==============================] - 0s 80us/step
# precision_modelo_independiente: 26.00%
# 100/100 [==============================] - 0s 91us/step
# precision_modelo_copia: 29.00%
# 200/200 [==============================] - 0s 74us/step
# precision_modelo_original: 24.00%
# 100/100 [==============================] - 0s 79us/step
# precision_modelo_independiente: 24.00%
# 100/100 [==============================] - 0s 87us/step
# precision_modelo_copia: 25.00%
# 200/200 [==============================] - 0s 57us/step
# precision_modelo_original: 24.00%
# 100/100 [==============================] - 0s 190us/step
# precision_modelo_independiente: 26.00%
# 100/100 [==============================] - 0s 100us/step
# precision_modelo_copia: 34.00%
# 200/200 [==============================] - 0s 88us/step
# precision_modelo_original: 23.50%
# 100/100 [==============================] - 0s 117us/step
# precision_modelo_independiente: 28.00%
# 100/100 [==============================] - 0s 132us/step
# precision_modelo_copia: 26.00%
# 200/200 [==============================] - 0s 114us/step
# precision_modelo_original: 23.50%
# 100/100 [==============================] - 0s 81us/step
# precision_modelo_independiente: 25.00%
# 100/100 [==============================] - 0s 93us/step
# precision_modelo_copia: 29.00%
# 200/200 [==============================] - 0s 60us/step
# precision_modelo_original: 24.00%
# 100/100 [==============================] - 0s 126us/step
# precision_modelo_independiente: 21.00%
# 100/100 [==============================] - 0s 91us/step
# precision_modelo_copia: 25.00%
# 200/200 [==============================] - 0s 61us/step
# precision_modelo_original: 24.50%
# 100/100 [==============================] - 0s 82us/step
# precision_modelo_independiente: 19.00%
# 100/100 [==============================] - 0s 87us/step
# precision_modelo_copia: 32.00%
# 200/200 [==============================] - 0s 66us/step
# precision_modelo_original: 24.50%
# 100/100 [==============================] - 0s 96us/step
# precision_modelo_independiente: 26.00%
# 100/100 [==============================] - 0s 88us/step
# precision_modelo_copia: 26.00%
# 200/200 [==============================] - 0s 61us/step
# precision_modelo_original: 25.00%
# 100/100 [==============================] - 0s 81us/step
# precision_modelo_independiente: 23.00%
# 100/100 [==============================] - 0s 121us/step
# precision_modelo_copia: 26.00%
# 200/200 [==============================] - 0s 74us/step
# precision_modelo_original: 25.00%
# 100/100 [==============================] - 0s 98us/step
# precision_modelo_independiente: 25.00%
# 100/100 [==============================] - 0s 89us/step
# precision_modelo_copia: 28.00%
# 200/200 [==============================] - 0s 68us/step
# precision_modelo_original: 25.00%
# 100/100 [==============================] - 0s 85us/step
# precision_modelo_independiente: 30.00%
# 100/100 [==============================] - 0s 106us/step
# precision_modelo_copia: 27.00%
# 200/200 [==============================] - 0s 85us/step
# precision_modelo_original: 25.00%
# 100/100 [==============================] - 0s 79us/step
# precision_modelo_independiente: 30.00%
# 100/100 [==============================] - 0s 120us/step
# precision_modelo_copia: 31.00%
# 200/200 [==============================] - 0s 92us/step
# precision_modelo_original: 25.00%
# 100/100 [==============================] - 0s 81us/step
# precision_modelo_independiente: 28.00%
# 100/100 [==============================] - 0s 135us/step
# precision_modelo_copia: 24.00%
# 200/200 [==============================] - 0s 87us/step
# precision_modelo_original: 25.00%
# 100/100 [==============================] - 0s 85us/step
# precision_modelo_independiente: 17.00%
# 100/100 [==============================] - 0s 85us/step
# precision_modelo_copia: 27.00%
# 200/200 [==============================] - 0s 61us/step
# precision_modelo_original: 24.50%
# 100/100 [==============================] - 0s 84us/step
# precision_modelo_independiente: 24.00%
# 100/100 [==============================] - 0s 87us/step
# precision_modelo_copia: 27.00%
# 200/200 [==============================] - 0s 66us/step
# precision_modelo_original: 24.50%
# 100/100 [==============================] - 0s 111us/step
# precision_modelo_independiente: 31.00%
# 100/100 [==============================] - 0s 89us/step
# precision_modelo_copia: 26.00%
# 200/200 [==============================] - 0s 76us/step
# precision_modelo_original: 25.00%
# 100/100 [==============================] - 0s 99us/step
# precision_modelo_independiente: 29.00%
# 100/100 [==============================] - 0s 317us/step
# precision_modelo_copia: 27.00%
# 200/200 [==============================] - 0s 100us/step
# precision_modelo_original: 25.00%
# 100/100 [==============================] - 0s 83us/step
# precision_modelo_independiente: 18.00%
# 100/100 [==============================] - 0s 91us/step
# precision_modelo_copia: 24.00%
# 200/200 [==============================] - 0s 59us/step
# precision_modelo_original: 25.00%
# 100/100 [==============================] - 0s 81us/step
# precision_modelo_independiente: 20.00%
# 100/100 [==============================] - 0s 90us/step
# precision_modelo_copia: 29.00%
# 200/200 [==============================] - 0s 67us/step
# precision_modelo_original: 25.00%
# 100/100 [==============================] - 0s 80us/step
# precision_modelo_independiente: 24.00%
# 100/100 [==============================] - 0s 83us/step
# precision_modelo_copia: 24.00%
# 200/200 [==============================] - 0s 64us/step
# precision_modelo_original: 24.50%
# 100/100 [==============================] - 0s 81us/step
# precision_modelo_independiente: 21.00%
# 100/100 [==============================] - 0s 96us/step
# precision_modelo_copia: 31.00%
# 200/200 [==============================] - 0s 66us/step
# precision_modelo_original: 24.50%
# 100/100 [==============================] - 0s 76us/step
# precision_modelo_independiente: 16.00%
# 100/100 [==============================] - 0s 91us/step
# precision_modelo_copia: 27.00%
# 200/200 [==============================] - 0s 73us/step
# precision_modelo_original: 24.50%
# 100/100 [==============================] - 0s 82us/step
# precision_modelo_independiente: 29.00%
# 100/100 [==============================] - 0s 90us/step
# precision_modelo_copia: 27.00%
# 200/200 [==============================] - 0s 61us/step
# precision_modelo_original: 24.50%
# 100/100 [==============================] - 0s 110us/step
# precision_modelo_independiente: 14.00%
# 100/100 [==============================] - 0s 120us/step
# precision_modelo_copia: 21.00%
# 200/200 [==============================] - 0s 73us/step
# precision_modelo_original: 24.00%
# 100/100 [==============================] - 0s 77us/step
# precision_modelo_independiente: 20.00%
# 100/100 [==============================] - 0s 88us/step
# precision_modelo_copia: 25.00%
# 200/200 [==============================] - 0s 70us/step
# precision_modelo_original: 24.50%
# 100/100 [==============================] - 0s 81us/step
# precision_modelo_independiente: 21.00%
# 100/100 [==============================] - 0s 91us/step
# precision_modelo_copia: 32.00%
# 200/200 [==============================] - 0s 67us/step
# precision_modelo_original: 24.00%
# 100/100 [==============================] - 0s 80us/step
# precision_modelo_independiente: 31.00%
# 100/100 [==============================] - 0s 85us/step
# precision_modelo_copia: 30.00%
# 200/200 [==============================] - 0s 72us/step
# precision_modelo_original: 24.00%
# 100/100 [==============================] - 0s 82us/step
# precision_modelo_independiente: 21.00%
# 100/100 [==============================] - 0s 87us/step
# precision_modelo_copia: 24.00%
# 200/200 [==============================] - 0s 72us/step
# precision_modelo_original: 24.00%
# 100/100 [==============================] - 0s 88us/step
# precision_modelo_independiente: 28.00%
# 100/100 [==============================] - 0s 92us/step
# precision_modelo_copia: 26.00%
# 200/200 [==============================] - 0s 59us/step
# precision_modelo_original: 24.00%
# 100/100 [==============================] - 0s 80us/step
# precision_modelo_independiente: 24.00%
# 100/100 [==============================] - 0s 114us/step
# precision_modelo_copia: 27.00%
# 200/200 [==============================] - 0s 75us/step
# precision_modelo_original: 24.00%
# 100/100 [==============================] - 0s 93us/step
# precision_modelo_independiente: 25.00%
# 100/100 [==============================] - 0s 82us/step
# precision_modelo_copia: 24.00%
# 200/200 [==============================] - 0s 72us/step
# precision_modelo_original: 24.00%
# 100/100 [==============================] - 0s 98us/step
# precision_modelo_independiente: 26.00%
# 100/100 [==============================] - 0s 99us/step
# precision_modelo_copia: 31.00%
# 200/200 [==============================] - 0s 84us/step
# precision_modelo_original: 24.50%
# 100/100 [==============================] - 0s 120us/step
# precision_modelo_independiente: 26.00%
# 100/100 [==============================] - 0s 85us/step
# precision_modelo_copia: 25.00%
# 200/200 [==============================] - 0s 68us/step
# precision_modelo_original: 24.50%
# 100/100 [==============================] - 0s 76us/step
# precision_modelo_independiente: 21.00%
# 100/100 [==============================] - 0s 90us/step
# precision_modelo_copia: 29.00%
# 200/200 [==============================] - 0s 79us/step
# precision_modelo_original: 24.50%
# 100/100 [==============================] - 0s 92us/step
# precision_modelo_independiente: 20.00%
# 100/100 [==============================] - 0s 91us/step
# precision_modelo_copia: 24.00%
# 200/200 [==============================] - 0s 111us/step
# precision_modelo_original: 25.00%
# 100/100 [==============================] - 0s 122us/step
# precision_modelo_independiente: 33.00%
# 100/100 [==============================] - 0s 90us/step
# precision_modelo_copia: 31.00%
# 200/200 [==============================] - 0s 69us/step
# precision_modelo_original: 25.50%
# 100/100 [==============================] - 0s 76us/step
# precision_modelo_independiente: 24.00%
# 100/100 [==============================] - 0s 91us/step
# precision_modelo_copia: 25.00%
# 200/200 [==============================] - 0s 85us/step
# precision_modelo_original: 26.00%
# 100/100 [==============================] - 0s 79us/step
# precision_modelo_independiente: 14.00%
# 100/100 [==============================] - 0s 88us/step
# precision_modelo_copia: 26.00%
# 200/200 [==============================] - 0s 96us/step
# precision_modelo_original: 26.50%
# 100/100 [==============================] - 0s 70us/step
# precision_modelo_independiente: 25.00%
# 100/100 [==============================] - 0s 79us/step
# precision_modelo_copia: 26.00%
# 200/200 [==============================] - 0s 60us/step
# precision_modelo_original: 27.00%
# 100/100 [==============================] - 0s 69us/step
# precision_modelo_independiente: 18.00%
# 100/100 [==============================] - 0s 82us/step
# precision_modelo_copia: 30.00%
# 200/200 [==============================] - 0s 80us/step
# precision_modelo_original: 27.00%
# 100/100 [==============================] - 0s 74us/step
# precision_modelo_independiente: 30.00%
# 100/100 [==============================] - 0s 81us/step
# precision_modelo_copia: 30.00%
# 200/200 [==============================] - 0s 68us/step
# precision_modelo_original: 27.00%
# 100/100 [==============================] - 0s 78us/step
# precision_modelo_independiente: 20.00%
# 100/100 [==============================] - 0s 117us/step
# precision_modelo_copia: 34.00%
# 200/200 [==============================] - 0s 60us/step
# precision_modelo_original: 27.50%
# 100/100 [==============================] - 0s 75us/step
# precision_modelo_independiente: 25.00%
# 100/100 [==============================] - 0s 99us/step
# precision_modelo_copia: 26.00%
# 200/200 [==============================] - 0s 61us/step
# precision_modelo_original: 27.00%
# 100/100 [==============================] - 0s 2ms/step
# precision_modelo_independiente: 30.00%
# 100/100 [==============================] - 0s 86us/step
# precision_modelo_copia: 33.00%
# 200/200 [==============================] - 0s 112us/step
# precision_modelo_original: 27.00%
# 100/100 [==============================] - 0s 82us/step
# precision_modelo_independiente: 28.00%
# 100/100 [==============================] - 0s 88us/step
# precision_modelo_copia: 22.00%
# 200/200 [==============================] - 0s 79us/step
# precision_modelo_original: 27.00%
# 100/100 [==============================] - 0s 99us/step
# precision_modelo_independiente: 28.00%
# 100/100 [==============================] - 0s 83us/step
# precision_modelo_copia: 30.00%
# 200/200 [==============================] - 0s 60us/step
# precision_modelo_original: 27.00%
# 100/100 [==============================] - 0s 73us/step
# precision_modelo_independiente: 26.00%
# 100/100 [==============================] - 0s 89us/step
# precision_modelo_copia: 29.00%
# 200/200 [==============================] - 0s 61us/step
# precision_modelo_original: 27.50%
# 100/100 [==============================] - 0s 103us/step
# precision_modelo_independiente: 24.00%
# 100/100 [==============================] - 0s 91us/step
# precision_modelo_copia: 36.00%
# 200/200 [==============================] - 0s 73us/step
# precision_modelo_original: 28.00%
# 100/100 [==============================] - 0s 87us/step
# precision_modelo_independiente: 20.00%
# 100/100 [==============================] - 0s 86us/step
# precision_modelo_copia: 29.00%
# 200/200 [==============================] - 0s 76us/step
# precision_modelo_original: 28.50%
# 100/100 [==============================] - 0s 81us/step
# precision_modelo_independiente: 26.00%
# 100/100 [==============================] - 0s 91us/step
# precision_modelo_copia: 29.00%
# 200/200 [==============================] - 0s 67us/step
# precision_modelo_original: 28.00%
# 100/100 [==============================] - 0s 82us/step
# precision_modelo_independiente: 22.00%
# 100/100 [==============================] - 0s 89us/step
# precision_modelo_copia: 26.00%
# 200/200 [==============================] - 0s 64us/step
# precision_modelo_original: 27.50%
# 100/100 [==============================] - 0s 80us/step
# precision_modelo_independiente: 30.00%
# 100/100 [==============================] - 0s 86us/step
# precision_modelo_copia: 35.00%
# 200/200 [==============================] - 0s 65us/step
# precision_modelo_original: 27.50%
# 100/100 [==============================] - 0s 81us/step
# precision_modelo_independiente: 27.00%
# 100/100 [==============================] - 0s 87us/step
# precision_modelo_copia: 34.00%
# 200/200 [==============================] - 0s 60us/step
# precision_modelo_original: 28.00%
# 100/100 [==============================] - 0s 79us/step
# precision_modelo_independiente: 24.00%
# 100/100 [==============================] - 0s 86us/step
# precision_modelo_copia: 27.00%
# 200/200 [==============================] - 0s 66us/step
# precision_modelo_original: 28.50%
# 100/100 [==============================] - 0s 85us/step
# precision_modelo_independiente: 23.00%
# 100/100 [==============================] - 0s 97us/step
# precision_modelo_copia: 29.00%
# 200/200 [==============================] - 0s 67us/step
# precision_modelo_original: 28.00%
# 100/100 [==============================] - 0s 84us/step
# precision_modelo_independiente: 24.00%
# 100/100 [==============================] - 0s 122us/step
# precision_modelo_copia: 26.00%
# 200/200 [==============================] - 0s 60us/step
# precision_modelo_original: 28.00%
# 100/100 [==============================] - 0s 94us/step
# precision_modelo_independiente: 25.00%
# 100/100 [==============================] - 0s 82us/step
# precision_modelo_copia: 31.00%
# 200/200 [==============================] - 0s 62us/step
# precision_modelo_original: 28.00%
# 100/100 [==============================] - 0s 98us/step
# precision_modelo_independiente: 21.00%
# 100/100 [==============================] - 0s 89us/step
# precision_modelo_copia: 30.00%
# 200/200 [==============================] - 0s 64us/step
# precision_modelo_original: 28.00%
# 100/100 [==============================] - 0s 80us/step
# precision_modelo_independiente: 22.00%
# 100/100 [==============================] - 0s 112us/step
# precision_modelo_copia: 30.00%
# 200/200 [==============================] - 0s 67us/step
# precision_modelo_original: 28.00%
# 100/100 [==============================] - 0s 110us/step
# precision_modelo_independiente: 20.00%
# 100/100 [==============================] - 0s 89us/step
# precision_modelo_copia: 30.00%
# 200/200 [==============================] - 0s 105us/step
# precision_modelo_original: 27.50%
# 100/100 [==============================] - 0s 71us/step
# precision_modelo_independiente: 27.00%
# 100/100 [==============================] - 0s 87us/step
# precision_modelo_copia: 27.00%
# 200/200 [==============================] - 0s 69us/step
# precision_modelo_original: 27.50%
# 100/100 [==============================] - 0s 77us/step
# precision_modelo_independiente: 19.00%
# 100/100 [==============================] - 0s 100us/step
# precision_modelo_copia: 24.00%
# 200/200 [==============================] - 0s 88us/step
# precision_modelo_original: 27.50%
# 100/100 [==============================] - 0s 86us/step
# precision_modelo_independiente: 33.00%
# 100/100 [==============================] - 0s 81us/step
# precision_modelo_copia: 33.00%
# 200/200 [==============================] - 0s 60us/step
# precision_modelo_original: 27.50%
# 100/100 [==============================] - 0s 77us/step
# precision_modelo_independiente: 24.00%
# 100/100 [==============================] - 0s 106us/step
# precision_modelo_copia: 26.00%
# 200/200 [==============================] - 0s 85us/step
# precision_modelo_original: 27.50%
# 100/100 [==============================] - 0s 76us/step
# precision_modelo_independiente: 26.00%
# 100/100 [==============================] - 0s 83us/step
# precision_modelo_copia: 29.00%
# 200/200 [==============================] - 0s 63us/step
# precision_modelo_original: 27.00%
# 100/100 [==============================] - 0s 79us/step
# precision_modelo_independiente: 24.00%
# 100/100 [==============================] - 0s 87us/step
# precision_modelo_copia: 32.00%
# 200/200 [==============================] - 0s 62us/step
# precision_modelo_original: 27.00%
# 100/100 [==============================] - 0s 80us/step
# precision_modelo_independiente: 29.00%
# 100/100 [==============================] - 0s 88us/step
# precision_modelo_copia: 31.00%
# 200/200 [==============================] - 0s 57us/step
# precision_modelo_original: 26.50%
# 100/100 [==============================] - 0s 77us/step
# precision_modelo_independiente: 24.00%
# 100/100 [==============================] - 0s 2ms/step
# precision_modelo_copia: 32.00%
# 200/200 [==============================] - 0s 59us/step
# precision_modelo_original: 27.00%
# 100/100 [==============================] - 0s 80us/step
# precision_modelo_independiente: 25.00%
# 100/100 [==============================] - 0s 82us/step
# precision_modelo_copia: 29.00%
# 200/200 [==============================] - 0s 59us/step
# precision_modelo_original: 27.00%
# 100/100 [==============================] - 0s 80us/step
# precision_modelo_independiente: 30.00%
# 100/100 [==============================] - 0s 94us/step
# precision_modelo_copia: 30.00%
# 200/200 [==============================] - 0s 63us/step
# precision_modelo_original: 27.00%
# 100/100 [==============================] - 0s 83us/step
# precision_modelo_independiente: 22.00%
# 100/100 [==============================] - 0s 87us/step
# precision_modelo_copia: 30.00%
# 200/200 [==============================] - 0s 66us/step
# precision_modelo_original: 27.50%
# 100/100 [==============================] - 0s 118us/step
# precision_modelo_independiente: 22.00%
# 100/100 [==============================] - 0s 112us/step
# precision_modelo_copia: 29.00%
# 200/200 [==============================] - 0s 62us/step
# precision_modelo_original: 27.50%
# 100/100 [==============================] - 0s 78us/step
# precision_modelo_independiente: 19.00%
# 100/100 [==============================] - 0s 205us/step
# precision_modelo_copia: 27.00%
# 200/200 [==============================] - 0s 64us/step
# precision_modelo_original: 28.00%
# 100/100 [==============================] - 0s 77us/step
# precision_modelo_independiente: 23.00%
# 100/100 [==============================] - 0s 83us/step
# precision_modelo_copia: 29.00%
# 200/200 [==============================] - 0s 57us/step
# precision_modelo_original: 28.00%
# 100/100 [==============================] - 0s 74us/step
# precision_modelo_independiente: 28.00%
# 100/100 [==============================] - 0s 79us/step
# precision_modelo_copia: 23.00%
# 200/200 [==============================] - 0s 63us/step
# precision_modelo_original: 28.00%
# 100/100 [==============================] - 0s 80us/step
# precision_modelo_independiente: 26.00%
# 100/100 [==============================] - 0s 78us/step
# precision_modelo_copia: 30.00%
# 200/200 [==============================] - 0s 63us/step
# precision_modelo_original: 28.00%
# 100/100 [==============================] - 0s 76us/step
# precision_modelo_independiente: 23.00%
# 100/100 [==============================] - 0s 85us/step
# precision_modelo_copia: 29.00%
# 200/200 [==============================] - 0s 62us/step
# precision_modelo_original: 28.00%
# 100/100 [==============================] - 0s 74us/step
# precision_modelo_independiente: 19.00%
# 100/100 [==============================] - 0s 85us/step
# precision_modelo_copia: 36.00%
# 200/200 [==============================] - 0s 63us/step
# precision_modelo_original: 28.00%
# 100/100 [==============================] - 0s 76us/step
# precision_modelo_independiente: 20.00%
# 100/100 [==============================] - 0s 85us/step
# precision_modelo_copia: 29.00%
# 200/200 [==============================] - 0s 66us/step
# precision_modelo_original: 28.00%
# 100/100 [==============================] - 0s 76us/step
# precision_modelo_independiente: 28.00%
# 100/100 [==============================] - 0s 89us/step
# precision_modelo_copia: 30.00%
# 200/200 [==============================] - 0s 61us/step
# precision_modelo_original: 28.00%
# 100/100 [==============================] - 0s 74us/step
# precision_modelo_independiente: 18.00%
# 100/100 [==============================] - 0s 81us/step
# precision_modelo_copia: 25.00%
# 200/200 [==============================] - 0s 93us/step
# precision_modelo_original: 28.00%
# 100/100 [==============================] - 0s 124us/step
# precision_modelo_independiente: 27.00%
# 100/100 [==============================] - 0s 87us/step
# precision_modelo_copia: 27.00%
# 200/200 [==============================] - 0s 60us/step
# precision_modelo_original: 28.00%
# 100/100 [==============================] - 0s 102us/step
# precision_modelo_independiente: 15.00%
# 100/100 [==============================] - 0s 92us/step
# precision_modelo_copia: 28.00%
# Mejora: 2.58%
# Mejora independiente: 4.45%

# %%
for i in range(t.max()):
    print(f'Tags en cajas tipo {i}: {index[index.boxoriginal==i].shape[0]/index.shape[0]*100:.2f}')
    print(f'Cajas tipo {i}: {X[t==i].shape[0]/X.shape[0]*100:.2f}')
# Out:
# Tags en cajas tipo 0: 6.66
# Cajas tipo 0: 9.09
# Tags en cajas tipo 1: 10.02
# Cajas tipo 1: 9.09
# Tags en cajas tipo 2: 9.99
# Cajas tipo 2: 9.09
# Tags en cajas tipo 3: 10.00
# Cajas tipo 3: 9.09
# Tags en cajas tipo 4: 9.99
# Cajas tipo 4: 9.09
# Tags en cajas tipo 5: 6.66
# Cajas tipo 5: 9.09
# Tags en cajas tipo 6: 6.66
# Cajas tipo 6: 9.09
# Tags en cajas tipo 7: 9.98
# Cajas tipo 7: 9.09
# Tags en cajas tipo 8: 10.01
# Cajas tipo 8: 9.09
# Tags en cajas tipo 9: 10.01
# Cajas tipo 9: 9.09

# %%
for i in range(t.max()):
    print(f'Tags en cajas tipo {i}: {index[index.boxoriginal==i].tagsread[:100]}')
# Out:
# Tags en cajas tipo 0: 5       1
# 31      1
# 33      1
# 51      1
# 76      1
#        ..
# 1355    1
# 1360    1
# 1362    1
# 1363    1
# 1381    1
# Name: tagsread, Length: 100, dtype: int64
# Tags en cajas tipo 1: 17     1
# 30     1
# 35     1
# 36     1
# 59     1
#       ..
# 957    1
# 969    1
# 971    1
# 974    1
# 990    1
# Name: tagsread, Length: 100, dtype: int64
# Tags en cajas tipo 2: 9       4
# 22      4
# 48      4
# 49      4
# 52      4
#        ..
# 1029    4
# 1043    4
# 1058    4
# 1099    4
# 1103    4
# Name: tagsread, Length: 100, dtype: int64
# Tags en cajas tipo 3: 15     3
# 19     3
# 23     3
# 26     3
# 27     3
#       ..
# 921    3
# 923    3
# 930    3
# 963    3
# 965    3
# Name: tagsread, Length: 100, dtype: int64
# Tags en cajas tipo 4: 4      3
# 7      3
# 21     3
# 32     3
# 39     3
#       ..
# 948    3
# 949    3
# 955    3
# 970    3
# 985    3
# Name: tagsread, Length: 100, dtype: int64
# Tags en cajas tipo 5: 50      4
# 71      4
# 73      4
# 80      4
# 103     4
#        ..
# 1392    4
# 1407    4
# 1411    4
# 1414    4
# 1419    4
# Name: tagsread, Length: 100, dtype: int64
# Tags en cajas tipo 6: 40      6
# 42      6
# 56      6
# 72      6
# 74      6
#        ..
# 1588    6
# 1591    6
# 1595    6
# 1615    6
# 1619    6
# Name: tagsread, Length: 100, dtype: int64
# Tags en cajas tipo 7: 2      5
# 18     5
# 20     5
# 28     5
# 44     5
#       ..
# 849    5
# 852    5
# 856    5
# 869    3
# 876    5
# Name: tagsread, Length: 100, dtype: int64
# Tags en cajas tipo 8: 0       10
# 14      10
# 16      10
# 24      10
# 34      10
#         ..
# 936     10
# 944     10
# 982     10
# 1004    10
# 1010    10
# Name: tagsread, Length: 100, dtype: int64
# Tags en cajas tipo 9: 1      15
# 3      15
# 6      15
# 8      15
# 11     15
#        ..
# 914    15
# 925    15
# 950    13
# 954    15
# 961    15
# Name: tagsread, Length: 100, dtype: int64

# %%
index[index.boxoriginal==i].head(50)
# Out:
#      frameini  framelst  boxnum  boxoriginal    L      W      H  read  tags  \
# 1           2         4      26            9  0.4  0.585  0.600     1    15
# 3           7         9      27            9  0.6  0.585  0.400     1    15
# 6          12        13       9            9  0.6  0.400  0.585     1    15
# 8          15        16      26            9  0.4  0.585  0.600     1    15
# 11         27        28       9            9  0.6  0.400  0.585     1    15
# 25         49        51      27            9  0.6  0.585  0.400     1    15
# 29         55        57       9            9  0.6  0.400  0.585     1    15
# 43         76        79      27            9  0.6  0.585  0.400     1    15
# 47         84        85       9            9  0.6  0.400  0.585     1    15
# 66        111       121      26            9  0.4  0.585  0.600     0    15
# 77        136       137      26            9  0.4  0.585  0.600     1    15
# 89        177       179      26            9  0.4  0.585  0.600     1    15
# 101       194       196      27            9  0.6  0.585  0.400     1    15
# 102       197       198      26            9  0.4  0.585  0.600     1    15
# 106       203       205      27            9  0.6  0.585  0.400     1    15
# 107       206       207      27            9  0.6  0.585  0.400     1    15
# 111       212       214      26            9  0.4  0.585  0.600     1    15
# 122       244       249       9            9  0.6  0.400  0.585     1    15
# 123       250       251       9            9  0.6  0.400  0.585     1    15
# 125       255       257      27            9  0.6  0.585  0.400     1    15
# 139       277       278      26            9  0.4  0.585  0.600     1    15
# 144       283       291       9            9  0.6  0.400  0.585     0    15
# 145       292       293      27            9  0.6  0.585  0.400     1    15
# 146       294       295       9            9  0.6  0.400  0.585     1    15
# 152       305       307      26            9  0.4  0.585  0.600     1    15
# 154       310       312      27            9  0.6  0.585  0.400     1    15
# 156       314       324      26            9  0.4  0.585  0.600     0    15
# 164       340       342      27            9  0.6  0.585  0.400     1    15
# 177       365       367      27            9  0.6  0.585  0.400     1    15
# 182       374       376      27            9  0.6  0.585  0.400     1    15
# 184       378       379       9            9  0.6  0.400  0.585     1    15
# 210       433       435      27            9  0.6  0.585  0.400     1    15
# 215       451       469       9            9  0.6  0.400  0.585     0    15
# 220       479       484      27            9  0.6  0.585  0.400     1    15
# 230       499       511      26            9  0.4  0.585  0.600     0    15
# 242       529       530      26            9  0.4  0.585  0.600     1    15
# 248       545       546       9            9  0.6  0.400  0.585     1    15
# 269       584       600       9            9  0.6  0.400  0.585     0    15
# 283       620       622      27            9  0.6  0.585  0.400     1    15
# 287       630       632      27            9  0.6  0.585  0.400     1    15
# 298       654       656      26            9  0.4  0.585  0.600     1    15
# 305       667       678      26            9  0.4  0.585  0.600     0    15
# 307       681       682       9            9  0.6  0.400  0.585     1    15
# 308       683       685      27            9  0.6  0.585  0.400     1    15
# 313       692       694       9            9  0.6  0.400  0.585     1    15
# 340       761       763       9            9  0.6  0.400  0.585     1    15
# 364       813       815      27            9  0.6  0.585  0.400     1    15
# 377       831       834       9            9  0.6  0.400  0.585     1    15
# 379       836       837      26            9  0.4  0.585  0.600     1    15
# 381       840       841      26            9  0.4  0.585  0.600     1    15
#
#      tagsread  readtime     despX     despY      theta  vhr    ha    hb    d  \
# 1          15   0.03983  0.040972  0.160102  21.612419    2  1.55  0.55  3.3
# 3          15   0.02296  0.134029 -0.121634 -30.319941    1  1.55  0.55  3.3
# 6          15   0.04277  0.054632 -0.190784 -28.103867    0  1.55  0.55  3.3
# 8          15   0.04277  0.006993  0.043028  36.409745    2  1.55  0.55  3.3
# 11         15   0.04068 -0.164511 -0.032152 -16.813992    2  1.55  0.55  3.3
# 25         15   0.04429  0.059907 -0.114639  12.099951    2  1.55  0.55  3.3
# 29         15   0.04666  0.147422  0.001961 -25.025301    0  1.55  0.55  3.3
# 43         15   0.04999  0.126045  0.138963 -35.906644    2  1.55  0.55  3.3
# 47         15   0.04277 -0.115452 -0.135786 -24.005346    0  1.55  0.55  3.3
# 66         14   0.07052  0.117095 -0.008755  41.212407    2  1.55  0.55  3.3
# 77         15   0.04305 -0.142845 -0.059256 -39.328311    0  1.55  0.55  3.3
# 89         15   0.04666 -0.029922  0.077974  17.561249    0  1.55  0.55  3.3
# 101        15   0.04638 -0.038475 -0.087417 -27.777976    2  1.55  0.55  3.3
# 102        15   0.04333  0.181925  0.190114 -14.696243    0  1.55  0.55  3.3
# 106        15   0.04666  0.032688 -0.133750 -14.259807    0  1.55  0.55  3.3
# 107        15   0.04040  0.172682 -0.188952 -29.943968    2  1.55  0.55  3.3
# 111        15   0.04638 -0.132714  0.074178  11.236256    0  1.55  0.55  3.3
# 122        15   0.02166  0.175510 -0.172386 -15.529651    1  1.55  0.55  3.3
# 123        15   0.04040 -0.165442 -0.128518 -11.403292    2  1.55  0.55  3.3
# 125        15   0.02742  0.035690 -0.111766 -29.291708    1  1.55  0.55  3.3
# 139        15   0.04277  0.120493 -0.051778 -16.207526    0  1.55  0.55  3.3
# 144        14   0.06567 -0.151014  0.156650 -20.168428    2  1.55  0.55  3.3
# 145        15   0.04277 -0.037261  0.140879 -15.158789    0  1.55  0.55  3.3
# 146        15   0.04068  0.062184 -0.040836 -17.396223    2  1.55  0.55  3.3
# 152        15   0.04192  0.099187 -0.005937  33.989505    2  1.55  0.55  3.3
# 154        15   0.04694  0.070869  0.073230 -15.537119    2  1.55  0.55  3.3
# 156        14   0.03971  0.040501 -0.014528  28.580491    1  1.55  0.55  3.3
# 164        15   0.03481 -0.063952 -0.067260  15.659338    1  1.55  0.55  3.3
# 177        15   0.04164  0.063125  0.017141  43.391030    2  1.55  0.55  3.3
# 182        15   0.04164  0.090532 -0.115660 -37.617394    2  1.55  0.55  3.3
# 184        15   0.04277  0.048511 -0.012888  13.895299    2  1.55  0.55  3.3
# 210        15   0.04666  0.020917 -0.060305 -32.630468    2  1.55  0.55  3.3
# 215        13   0.08281 -0.167624 -0.147860  -7.953152    1  1.55  0.55  3.3
# 220        15   0.04327  0.035541 -0.190477 -41.788719    1  1.55  0.55  3.3
# 230        13   0.05404  0.074060  0.057123  41.300006    1  1.55  0.55  3.3
# 242        15   0.04277 -0.004616 -0.070746  26.687896    0  1.55  0.55  3.3
# 248        15   0.04305  0.132957  0.062417  12.181048    0  1.55  0.55  3.3
# 269        13   0.07322 -0.049983 -0.171521   6.089409    1  1.55  0.55  3.3
# 283        15   0.04638  0.131423  0.014796  22.695877    0  1.55  0.55  3.3
# 287        15   0.04638 -0.067642  0.136664 -18.252812    2  1.55  0.55  3.3
# 298        15   0.04638  0.149527  0.054182  42.268532    0  1.55  0.55  3.3
# 305        14   0.06493 -0.122693  0.171446   3.603393    1  1.55  0.55  3.3
# 307        15   0.04277 -0.048347 -0.162848   5.184644    2  1.55  0.55  3.3
# 308        15   0.03718 -0.127136  0.125802   0.772781    1  1.55  0.55  3.3
# 313        15   0.04638  0.034703 -0.119247  42.874845    0  1.55  0.55  3.3
# 340        15   0.04638 -0.075776  0.144812 -37.978410    0  1.55  0.55  3.3
# 364        15   0.02533 -0.044208  0.066787  29.600410    1  1.55  0.55  3.3
# 377        15   0.05055 -0.146605 -0.153684 -17.169653    0  1.55  0.55  3.3
# 379        15   0.04277 -0.010975 -0.120571   4.103637    0  1.55  0.55  3.3
# 381        15   0.04277 -0.146943  0.077807  30.103103    2  1.55  0.55  3.3
#
#      numframes
# 1            3
# 3            3
# 6            2
# 8            2
# 11           2
# 25           3
# 29           3
# 43           4
# 47           2
# 66          11
# 77           2
# 89           3
# 101          3
# 102          2
# 106          3
# 107          2
# 111          3
# 122          6
# 123          2
# 125          3
# 139          2
# 144          9
# 145          2
# 146          2
# 152          3
# 154          3
# 156         11
# 164          3
# 177          3
# 182          3
# 184          2
# 210          3
# 215         19
# 220          6
# 230         13
# 242          2
# 248          2
# 269         17
# 283          3
# 287          3
# 298          3
# 305         12
# 307          2
# 308          3
# 313          3
# 340          3
# 364          3
# 377          4
# 379          2
# 381          2
